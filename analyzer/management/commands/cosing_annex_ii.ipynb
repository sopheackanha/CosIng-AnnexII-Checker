# %%
import pandas as pd

# %%
# load data
df = pd.read_csv(r"D:\cos-ing-checker\cosing_checker\datasets\COSING_Annex_II_v2.txt", skiprows=4)
df.head()
# Out:
#    Reference Number                                Chemical name / INN  \
# 0                 1               N-(5-Chlorobenzoxazol-2-yl)acetamide
# 1                 2  (2-Acetoxyethyl)trimethylammonium hydroxide (A...
# 2                 3                            Deanol aceglumate (INN)
# 3                 4                               Spironolactone (INN)
# 4                 5  [4-(4-Hydroxy-3-iodophenoxy)-3,5-diiodophenyl]...
#
#    CAS Number  EC Number      Regulation Other Directives/Regulations  \
# 0  35783-57-4          -  (EC) 2009/1223                          NaN
# 1     51-84-3  200-128-9  (EC) 2009/1223                          NaN
# 2   3342-61-8  222-085-5  (EC) 2009/1223                          NaN
# 3     52-01-7  200-133-6  (EC) 2009/1223                          NaN
# 4     51-24-1  200-086-1  (EC) 2009/1223                          NaN
#
#   SCCS opinions                                Chemical/IUPAC Name  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN  Triiodothyroacetic acid; (4-(4-Hydroxy-3-iodop...
#
#   Identified INGREDIENTS or substances e.g.  CMR Update Date
# 0                                       NaN  NaN  17/10/2010
# 1                                      ,,,,  NaN  17/10/2010
# 2                                       NaN  NaN  15/10/2010
# 3                            SPIRONOLACTONE  NaN  15/10/2010
# 4                                       NaN  NaN  17/10/2010

# %%
# save as csv file
df.to_csv(r"D:\cos-ing-checker\cosing_checker\datasets\COSING_Annex_II_v2.csv", index=False)
# load the csv file
df.
